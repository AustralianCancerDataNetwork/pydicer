# %% [markdown]
# # Example Notebook to run PyDicer
#
# This notebook provides a basic example to run the PyDicer pipeline using some test data.

# %%
import sys
sys.path.insert(0, "..")

from pathlib import Path

from pydicer import PyDicer

from pydicer.input.test import TestInput

# %% [markdown]
# ## Setup working directory
#
# First we'll create a directory for our project. Change the `directory` location to a folder on your
# system where you'd like PyDicer to work with this data.

# %%
directory = Path("./data")

# %% [markdown]
# ## Create a PyDicer object
#
# The PyDicer class provides all functionlity to run the pipeline and work with the data stored and
# converted in your project directory

# %%
pydicer = PyDicer(directory)

# %% [markdown]
# ## Fetch some data
#
# A TestInput class is provided in pydicer to download some sample data to work with. Several other
# input classes exist if you'd like to retrieve DICOM data for conversion from somewhere else, [see
# the docs for information on how these work](https://australiancancerdatanetwork.github.io/pydicer/html/input.html).

# %%
dicom_directory = directory.joinpath("dicom")
test_input = TestInput(dicom_directory)
test_input.fetch_data()

# Add the input DICOM location to the pydicer object
pydicer.add_input(dicom_directory)
# Out:
# Directory not empty, won't download files

# %% [markdown]
# ## Run the pipeline
#
# The function runs the entire PyDicer pipeline on the test DICOM data. This includes:
# - Preprocessing the DICOM data (data which can't be handled or is corrupt will be placed in Quarantine)
# - Convert the data to Nifti format (see the output in the `data` directory)
# - Visualise the data (png files will be placed alongside the converted Nifti files)
# - Compute Radiomics features (Results are stored in a csv alongside the converted structures)
# - Compute Dose Volume Histograms (results are stored alongside converted dose data)
#
# > Note that the entire Pipeline can be quite time consuming to run. Depending on your project's
# > dataset you will likely want to run only portions of the pipeline with finer control over each
# > step. For this reason we only run the pipeline for one patient here as a demonstration.

# %%
#ydicer.run_pipeline(patient="HNSCC-01-0019")
pydicer.run_pipeline()
# Out:
# 2022-08-15 14:16:56.794 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 0 with name: Marked_Iso
# 2022-08-15 14:16:56.795 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:152 - This is not a closed planar structure, skipping.
# 2022-08-15 14:16:56.796 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 1 with name: Calc_pt
# 2022-08-15 14:16:56.796 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:152 - This is not a closed planar structure, skipping.
# 2022-08-15 14:16:56.811 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 2 with name: External
# 2022-08-15 14:17:00.725 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 3 with name: GTV1
# 2022-08-15 14:17:01.422 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 4 with name: RT_Parotid
# 2022-08-15 14:17:02.024 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 5 with name: LT_Parotid
# 2022-08-15 14:17:02.609 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 6 with name: Brainstem
# 2022-08-15 14:17:03.196 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 7 with name: Cord
# 2022-08-15 14:17:03.811 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 8 with name: Optic_Nerve
# 2022-08-15 14:17:04.406 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 9 with name: CTV70
# 2022-08-15 14:17:05.112 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 10 with name: CTV63
# 2022-08-15 14:17:06.009 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 11 with name: ctv_57
# 2022-08-15 14:17:06.609 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 12 with name: larynx_avoidance
# 2022-08-15 14:17:07.155 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 13 with name: chiasm
# 2022-08-15 14:17:07.798 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 14 with name: CTV63_Sep
# 2022-08-15 14:17:08.784 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 15 with name: Brain
# 2022-08-15 14:17:09.786 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 16 with name: Mandible
# 2022-08-15 14:17:10.511 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 17 with name: PTV70
# 2022-08-15 14:17:11.333 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 18 with name: PTV63
# 2022-08-15 14:17:12.351 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 19 with name: PTV57
# 2022-08-15 14:17:12.999 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 20 with name: +1
# 2022-08-15 14:17:17.726 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 21 with name: -.3
# 2022-08-15 14:17:20.534 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 22 with name: Ring
# 2022-08-15 14:17:27.595 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 23 with name: Post_Neck
# 2022-08-15 14:17:28.260 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 24 with name: Oral_Avoid
# 2022-08-15 14:17:28.867 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 25 with name: Rt_Sup_Prtd
# 2022-08-15 14:17:29.439 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 26 with name: Rt_Deep_Prtd
# 2022-08-15 14:17:29.982 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 27 with name: Lt_Sup_Prtd
# 2022-08-15 14:17:30.572 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 28 with name: Lt_Deep_Prtd
# 2022-08-15 14:17:31.119 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 29 with name: Cord_EXPANDED
# 2022-08-15 14:17:31.739 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 30 with name: hotspot
# 2022-08-15 14:17:32.316 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 31 with name: cool_off
# 2022-08-15 14:17:32.887 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 32 with name: cold
# 2022-08-15 14:17:33.444 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 33 with name: cold_hot
# 2022-08-15 14:17:33.445 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:137 - No contour sequence found for this structure, skipping.
# WARNING: In /Users/runner/work/1/sitk-build/ITK-prefix/include/ITK-5.2/itkImageSeriesReader.hxx, line 480
# ImageSeriesReader (0x7fc0298a7790): Non uniform sampling or missing slices detected,  maximum nonuniformity:0.000641026
#
# WARNING: In /Users/runner/work/1/sitk-build/ITK-prefix/include/ITK-5.2/itkImageSeriesReader.hxx, line 480
# ImageSeriesReader (0x7fc02a08ad00): Non uniform sampling or missing slices detected,  maximum nonuniformity:0.000641026
#
# Unable to convert series for patient: HNSCC-01-0176 with UID: 1.3.6.1.4.1.14519.5.2.1.1706.8040.275221863632386028471878740582
# 2 slices at location 0.0 containing different pixel data.
# Traceback (most recent call last):
#   File "../pydicer/convert/data.py", line 316, in convert
#     series_files = handle_missing_slice(df_files)
#   File "../pydicer/convert/data.py", line 100, in handle_missing_slice
#     raise (
# ValueError: 2 slices at location 0.0 containing different pixel data.
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/1.000000-SCOUTNECK-ORALNASO WCON-40582/1-1.dcm: 2 slices at location 0.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/1.000000-SCOUTNECK-ORALNASO WCON-40582/2-1.dcm: 2 slices at location 0.0 containing different pixel data.. Placing file into Quarantine folder...
# Unable to convert series for patient: HNSCC-01-0176 with UID: 1.3.6.1.4.1.14519.5.2.1.1706.8040.332585055459336001464892678433
# 2 slices at location -155.0 containing different pixel data.
# Traceback (most recent call last):
#   File "../pydicer/convert/data.py", line 316, in convert
#     series_files = handle_missing_slice(df_files)
#   File "../pydicer/convert/data.py", line 100, in handle_missing_slice
#     raise (
# ValueError: 2 slices at location -155.0 containing different pixel data.
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-001.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-002.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-003.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-004.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-005.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-006.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-007.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-008.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-009.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-010.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-011.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-012.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-013.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-014.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-015.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-016.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-017.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-018.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-019.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-020.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-021.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-022.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-023.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-024.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-025.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-026.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-027.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-028.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-029.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-030.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-031.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-032.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-033.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-034.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-035.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-036.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-037.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-038.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-039.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-040.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-041.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-042.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-043.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-044.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1-045.dcm: 2 slices at location -155.0 containing different pixel data.. Placing file into Quarantine folder...
# Error parsing file data/dicom/HNSCC/HNSCC-01-0176/03-05-2004-NA-CT HEAD  NECK WCON-85342/3.000000-BONE-78433/1
| DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 13 with name: CTV_57_Gy
# 2022-08-15 14:23:16.078 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 14 with name: Rt_Parotid_Sub
# 2022-08-15 14:23:17.020 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 15 with name: Rt_Parotid
# 2022-08-15 14:23:18.025 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 16 with name: Lt_Parotid_Sub
# 2022-08-15 14:23:19.057 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 17 with name: Lt_Parotid
# 2022-08-15 14:23:20.090 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 18 with name: Cord
# 2022-08-15 14:23:21.399 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 19 with name: Brainstem
# 2022-08-15 14:23:22.970 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 20 with name: L_lens
# 2022-08-15 14:23:24.071 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 21 with name: L_ON
# 2022-08-15 14:23:25.078 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 22 with name: R_lens
# 2022-08-15 14:23:26.159 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 23 with name: R_ON
# 2022-08-15 14:23:27.172 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 24 with name: Optic_chiasm
# 2022-08-15 14:23:28.311 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 25 with name: R_cochlea
# 2022-08-15 14:23:29.661 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 26 with name: L_cochlea
# 2022-08-15 14:23:30.711 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 27 with name: bridge
# 2022-08-15 14:23:31.680 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 28 with name: External
# 2022-08-15 14:23:36.102 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 29 with name: contract
# 2022-08-15 14:23:40.737 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 30 with name: total_ptv
# 2022-08-15 14:23:42.363 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 31 with name: expand
# 2022-08-15 14:23:44.782 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 32 with name: NT
# 2022-08-15 14:23:50.286 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 33 with name: cord_expand
# 2022-08-15 14:23:51.441 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 34 with name: braintstem_expand
# 2022-08-15 14:23:52.590 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 35 with name: uni
# 2022-08-15 14:23:53.643 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 36 with name: avoid
# 2022-08-15 14:23:54.687 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 37 with name: uni_57
# 2022-08-15 14:23:55.729 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 38 with name: post_neck
# 2022-08-15 14:23:57.036 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 39 with name: max_50
# 2022-08-15 14:23:58.244 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 40 with name: cool
# 2022-08-15 14:23:59.323 | DEBUG    | platipy.dicom.io.rtstruct_to_nifti:transform_point_set_from_dicom_struct:134 - Converting structure 41 with name: copy

# %% [markdown]
# ## Prepare a dataset
#
# Datasets which are extracted in DICOM format can often be a bit messy and require some cleaning up
# after conversion. Exactly what data objects to extract for the clean dataset will differ by project
# but here we use a somewhat common approach of extracting the latest structure set for each patient
# and the image linked to that.
#
# The resulting dataset is stored in a folder with your dataset name (`clean` for this example).

# %%
pydicer.dataset.prepare(dataset_name="clean", preparation_function="rt_latest_dose")
# Out:
# ../../../data/HNSCC-01-0199/doses/c16e76
# data/clean/HNSCC-01-0199/doses/c16e76
# ../../../data/HNSCC-01-0199/plans/664e96
# data/clean/HNSCC-01-0199/plans/664e96
# ../../../data/HNSCC-01-0199/structures/06e49c
# data/clean/HNSCC-01-0199/structures/06e49c
# ../../../data/HNSCC-01-0199/images/72b0f9
# data/clean/HNSCC-01-0199/images/72b0f9
# ../../../data/HNSCC-01-0019/doses/309e1a
# data/clean/HNSCC-01-0019/doses/309e1a
# ../../../data/HNSCC-01-0019/plans/57b99f
# data/clean/HNSCC-01-0019/plans/57b99f
# ../../../data/HNSCC-01-0019/structures/7cdcd9
# data/clean/HNSCC-01-0019/structures/7cdcd9
# ../../../data/HNSCC-01-0019/images/b281ea
# data/clean/HNSCC-01-0019/images/b281ea
# ../../../data/HNSCC-01-0176/doses/833a74
# data/clean/HNSCC-01-0176/doses/833a74
# ../../../data/HNSCC-01-0176/plans/a6b346
# data/clean/HNSCC-01-0176/plans/a6b346
# ../../../data/HNSCC-01-0176/structures/cbbf5b
# data/clean/HNSCC-01-0176/structures/cbbf5b
# ../../../data/HNSCC-01-0176/images/c4ffd0
# data/clean/HNSCC-01-0176/images/c4ffd0

# %% [markdown]
# ## Analyse the dataset
#
# The pipeline computes first-order radiomics features by default, as well as dose volume histograms.
# Here we can extract out the results easily into a Pandas DataFrame for analysis.

# %%
# Display the DataFrame of radiomics computed
df_radiomics = pydicer.analyse.get_all_computed_radiomics_for_dataset(dataset_name="clean")
df_radiomics
# Out:
#       Contour        Patient ImageHashedUID StructHashedUID  \
# 5          +1  HNSCC-01-0019         b281ea          7cdcd9
# 4         -.3  HNSCC-01-0019         b281ea          7cdcd9
# 27      Brain  HNSCC-01-0019         b281ea          7cdcd9
# 28  Brainstem  HNSCC-01-0019         b281ea          7cdcd9
# 25      CTV63  HNSCC-01-0019         b281ea          7cdcd9
# ..        ...            ...            ...             ...
# 18     max_50  HNSCC-01-0199         72b0f9          06e49c
# 25  post_neck  HNSCC-01-0199         72b0f9          06e49c
# 15  total_ptv  HNSCC-01-0199         72b0f9          06e49c
# 31        uni  HNSCC-01-0199         72b0f9          06e49c
# 6      uni_57  HNSCC-01-0199         72b0f9          06e49c
#
#     firstorder|10Percentile  firstorder|90Percentile  firstorder|Energy  \
# 5                    -999.0                    339.0       5.178130e+11
# 4                     -68.0                    669.0       1.587794e+11
# 27                     24.0                     70.0       6.420357e+08
# 28                     14.0                     46.0       1.860914e+07
# 25                    -65.0                    308.0       1.346678e+10
# ..                      ...                      ...                ...
# 18                   -631.5                    250.0       3.920070e+07
# 25                    -28.0                    352.0       9.173127e+09
# 15                   -262.0                    110.0       2.146647e+10
# 31                   -438.0                    439.0       2.621229e+09
# 6                     -78.0                     60.0       1.407273e+07
#
#     firstorder|Entropy  firstorder|InterquartileRange  firstorder|Kurtosis  \
# 5             4.785593                         407.00             4.227583
# 4             4.415742                          73.00             9.756706
# 27            1.698910                          21.00           266.544166
# 28            1.275139                          17.00           133.476694
# 25            4.124500                          60.00            10.650191
# ..                 ...                            ...                  ...
# 18            5.282432                         442.25             2.732802
# 25            3.457737                          32.00            12.417805
# 15            4.334682                         109.00             8.478738
# 31            4.976606                         115.00             5.307995
# 6             2.960550                          82.00            13.703832
#
#     ...  firstorder|Mean  firstorder|Median  firstorder|Minimum  \
# 5   ...      -127.630179               18.0             -1024.0
# 4   ...       142.809678               41.0             -1024.0
# 27  ...        45.375629               40.0              -849.0
# 28  ...        30.442222               30.0               -26.0
# 25  ...        58.805603               37.0             -1014.0
# ..  ...              ...                ...                 ...
# 18  ...       -69.705357               40.5              -905.0
# 25  ...       107.575110               45.0              -891.0
# 15  ...       -17.168810               25.0             -1011.0
# 31  ...        26.582496               35.0              -996.0
# 6   ...         3.607886               16.0              -125.0
#
#     firstorder|Range  firstorder|RobustMeanAbsoluteDeviation  \
# 5             4000.0                              276.691595
# 4             4000.0                               77.747524
# 27            2151.0                                9.055957
# 28             581.0                                7.063362
# 25            3990.0                               36.643247
# ..               ...                                     ...
# 18            1382.0                              190.102584
# 25            2488.0                               31.982812
# 15            2717.0                               49.117380
# 31            2616.0                               84.668009
# 6              913.0                               33.341364
#
#     firstorder|RootMeanSquared  firstorder|Skewness  firstorder|TotalEnergy  \
# 5                   565.017962             0.216289            1.481475e+12
# 4                   410.946993             1.886750            4.542715e+11
# 27                   57.813075            10.351606            1.836879e+09
# 28                   33.431514             3.682653            5.324118e+07
# 25                  287.047711             0.524907            3.852878e+10
# ..                         ...                  ...                     ...
# 18                  341.568097            -0.882366            9.346176e+07
# 25                  243.143026             2.970106            2.187044e+10
# 15                  304.491275            -0.258097            5.118006e+10
# 31                  356.600440            -0.164137            6.249497e+09
# 6                    55.522471             0.614211            3.355200e+07
#
#     firstorder|Uniformity  firstorder|Variance
# 5                0.076182        302955.835075
# 4                0.111299        148482.826970
# 27               0.427362          1283.403884
# 28               0.491624           190.937232
# 25               0.125626         78938.289561
# ..                    ...                  ...
# 18               0.033943        111809.928067
# 25               0.205189         47546.126922
# 15               0.104536         92420.168569
# 31               0.078507        126457.244989
# 6                0.147677          3069.727955
#
# [106 rows x 22 columns]

# %%
# Extract the D95, D50 and V3 dose metrics
df_dose_metrics = pydicer.analyse.compute_dose_metrics(dataset_name="clean", d_point=[95, 50], v_point=[3])
df_dose_metrics
# Out:
#            patient struct_hash      label           cc       mean   D95   D50  \
# 0    HNSCC-01-0019      7cdcd9         +1  4640.553474  29.679710   0.0  25.3
# 1    HNSCC-01-0019      7cdcd9        -.3  2689.948082  43.784290  11.3  43.3
# 2    HNSCC-01-0019      7cdcd9      Brain   549.576759  24.043829   7.6  22.3
# 3    HNSCC-01-0019      7cdcd9  Brainstem    47.636032  39.998913  28.9  39.2
# 4    HNSCC-01-0019      7cdcd9      CTV63   467.602730  71.274086  66.1  71.5
# ..             ...         ...        ...          ...        ...   ...   ...
# 101  HNSCC-01-0199      06e49c     max_50     0.801086  44.847424  38.9  44.9
# 102  HNSCC-01-0199      06e49c  post_neck   369.942188  23.905859  12.4  23.4
# 103  HNSCC-01-0199      06e49c  total_ptv   552.015305  67.680992  57.4  71.0
# 104  HNSCC-01-0199      06e49c        uni    49.145222  70.718925  66.1  71.3
# 105  HNSCC-01-0199      06e49c     uni_57    10.883808  59.222034  56.6  59.4
#
#               V3
# 0    3709.925652
# 1    2688.291550
# 2     549.553871
# 3      47.636032
# 4     467.602730
# ..           ...
# 101     0.801086
# 102   369.849205
# 103   552.015305
# 104    49.145222
# 105    10.883808
#
# [106 rows x 8 columns]

# %%
# Out:
# array(['HNSCC-01-0019', 'HNSCC-01-0176', 'HNSCC-01-0199'], dtype=object)
